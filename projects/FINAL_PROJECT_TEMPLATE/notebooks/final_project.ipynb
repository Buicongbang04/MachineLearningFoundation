# %% [markdown]
# # Final Project — *Your Project Title*
#
# **Author:** _your name_
# **Date:** _yyyy-mm-dd_
#
# This notebook walks through the full pipeline of your final project: problem framing, EDA, preprocessing, baseline, model comparison, evaluation, and error analysis.
#
# Adapt the section headings to your dataset, but keep the order — graders use it as a checklist against the rubric in `report.md`.

# %% [markdown]
# ## 1. Problem Statement

# %% [markdown]
# _Describe the problem in one paragraph._

# %% [markdown]
# ## 2. Imports and Seeds

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

SEED = 42
np.random.seed(SEED)

sns.set_theme(style='whitegrid')
plt.rcParams['figure.figsize'] = (8, 5)

# %% [markdown]
# ## 3. Load Data

# %%
# from src.data_preprocessing import load_data
# df = load_data('path/to/your/data.csv')
# df.head()

# %% [markdown]
# ## 4. Exploratory Data Analysis

# %% [markdown]
# ## 5. Preprocessing and Feature Engineering

# %% [markdown]
# ## 6. Train / Validation / Test Split

# %% [markdown]
# ## 7. Baseline Model

# %% [markdown]
# ## 8. Model Comparison

# %% [markdown]
# ## 9. Evaluation on Test Set

# %% [markdown]
# ## 10. Error Analysis

# %% [markdown]
# ## 11. Conclusions and Next Steps
